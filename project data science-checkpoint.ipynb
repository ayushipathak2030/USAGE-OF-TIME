# %%
import pandas as pd
import numpy as np
df=pd.read_csv("F:\project python\TimeUse.csv")
df
# Out:
#         SEX                                  GEO/ACL00  Total Personal care  \
# 0     Males                                    Belgium  24:00         10:45
# 1     Males                                   Bulgaria  24:00         11:54
# 2     Males  Germany (including  former GDR from 1991)  24:00         10:40
# 3     Males                                    Estonia  24:00         10:35
# 4     Males                                      Spain  24:00         11:11
# 5     Males                                     France  24:00         11:44
# 6     Males                                      Italy  24:00         11:16
# 7     Males                                     Latvia  24:00         10:46
# 8     Males                                  Lithuania  24:00         10:53
# 9     Males                                     Poland  24:00         10:44
# 10    Males                                   Slovenia  24:00         10:31
# ...

# %%
df.head()
# Out:
#      SEX                                  GEO/ACL00  Total Personal care  \
# 0  Males                                    Belgium  24:00         10:45
# 1  Males                                   Bulgaria  24:00         11:54
# 2  Males  Germany (including  former GDR from 1991)  24:00         10:40
# 3  Males                                    Estonia  24:00         10:35
# 4  Males                                      Spain  24:00         11:11
#
#   Sleep Eating Other and/or unspecified personal care  \
# 0  8:15   1:49                                   0:42
# 1  9:08   2:07                                   0:39
# 2  8:08   1:43                                   0:49
# 3  8:24   1:19                                   0:52
# 4  8:36   1:47                                   0:48
#
#   Employment, related activities and travel as part of/during main and second job  \
# 0                                               3:07
# 1                                               3:32
# ...

# %%
df.tail()
# Out:
#         SEX       GEO/ACL00  Total Personal care Sleep Eating  \
# 23  Females          Poland  24:00         11:03  8:35   1:34
# 24  Females        Slovenia  24:00         10:32  8:25   1:26
# 25  Females         Finland  24:00         10:38  8:32   1:19
# 26  Females  United Kingdom  24:00         10:43  8:27   1:26
# 27  Females          Norway  24:00         10:27  8:10   1:20
#
#    Other and/or unspecified personal care  \
# 23                                   0:54
# 24                                   0:41
# 25                                   0:47
# 26                                   0:50
# 27                                   0:56
#
#    Employment, related activities and travel as part of/during main and second job  \
# 23                                               2:15
# 24                                               2:42
# 25                                               2:33
# 26                                               2:24
# ...

# %%
new_df=df.replace([-1,2],np.nan)
new_df
# Out:
#         SEX                                  GEO/ACL00  Total Personal care  \
# 0     Males                                    Belgium  24:00         10:45
# 1     Males                                   Bulgaria  24:00         11:54
# 2     Males  Germany (including  former GDR from 1991)  24:00         10:40
# 3     Males                                    Estonia  24:00         10:35
# 4     Males                                      Spain  24:00         11:11
# 5     Males                                     France  24:00         11:44
# 6     Males                                      Italy  24:00         11:16
# 7     Males                                     Latvia  24:00         10:46
# 8     Males                                  Lithuania  24:00         10:53
# 9     Males                                     Poland  24:00         10:44
# 10    Males                                   Slovenia  24:00         10:31
# ...

# %%
import matplotlib.pyplot as plt
df['Sleep'].hist(bins=10)

# %%
x = df["SEX"] 
y = df["Eating"] 
plt.scatter(x, y, label= "stars", color= "m",  
            marker= "*", s=30)

# %%
x = df["SEX"] 
y = df["Eating"] 
plt.plot(x,y)
plt.show()

# %%
plt.bar(df["SEX"],color='red',height=20)
plt.bar(df["Sleep"],color='green',height=10)
plt.show()
